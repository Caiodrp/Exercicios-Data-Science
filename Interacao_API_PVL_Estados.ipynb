# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) 
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

r = requests.get(url)
data_json = r.json()
r.status_code
# Out:
# 200

# %%
rj_cidades = pd.DataFrame(data_json['items'])
rj_cidades
# Out:
#      id_pleito tipo_interessado      interessado  cod_ibge  uf num_pvl  \
# 0        10478        Município  Duque de Caxias   3301702  RJ    None
# 1        13443        Município      Nova Iguaçu   3303500  RJ    None
# 2        11419        Município   Rio de Janeiro   3304557  RJ    None
# 3        11581        Município     Belford Roxo   3300456  RJ    None
# 4        11030        Município        Cantagalo   3301108  RJ    None
# ..         ...              ...              ...       ...  ..     ...
# 220      13594        Município   Rio de Janeiro   3304557  RJ    None
# 221      11946        Município        Vassouras   3306206  RJ    None
# 222       4924        Município   Rio de Janeiro   3304557  RJ    None
# 223       5843        Município           Maricá   3302700  RJ    None
# 224       5864        Município      Duas Barras   3301603  RJ    None
#
#                              status          num_processo  \
# ...

# %%
# 2) Status mais frequentes
rj_cidades.status.value_counts()
# Out:
# Deferido                                                 88
# Arquivado                                                53
# Regularizado                                             25
# Arquivado por decurso de prazo                           23
# Deferido (PVL-IF)                                        14
# Encaminhado à PGFN com manifestação técnica favorável    11
# Arquivado a pedido                                        5
# Em retificação pelo interessado                           3
# Pendente de regularização                                 1
# Processo pendente de distribuição                         1
# Em retificação pelo interessado (PVL-IF)                  1
# Name: status, dtype: int64

# %%
# 3) Anos dos Status
ano_status = rj_cidades['data_status'].str.slice(start=-4)
ano_status
# Out:
# 0      2020
# 1      2002
# 2      2008
# 3      2007
# 4      2014
#        ...
# 220    2007
# 221    2013
# 222    2006
# 223    2010
# 224    2008
# Name: data_status, Length: 225, dtype: object

# %%
# 4) Frequência de cada ano

ano_status.value_counts()
# Out:
# 2008    37
# 2007    29
# 2014    20
# 2010    19
# 2019    17
# 2013    15
# 2020    15
# 2012    13
# 2011    10
# 2015     9
# 2009     9
# 2021     5
# 2017     5
# 2016     4
# 2018     4
# 2002     4
# 2022     4
# 2006     4
# 2004     1
# 2003     1
# Name: data_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Definindo a função
def dados_pvl (uf,interessado):#str,str
    url= f'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={interessado}'
    r = requests.get(url)
    data_json = r.json()
    return pd.DataFrame(data_json['items'])

# %%
# 2) Solicitações para o estado de MG estão com status 'Arquivado por decurso de prazo'
mg = dados_pvl('MG','Estado')
mg.loc[mg['status'] == 'Arquivado por decurso de prazo']
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 5      20534           Estado  Minas Gerais        31  MG
#
#                 num_pvl                          status          num_processo  \
# 5  00000.000000/2017-69  Arquivado por decurso de prazo  17944.001113/2015-60
#
#          data_protocolo                tipo_operacao finalidade  \
# 5  2017-07-26T03:00:00Z  Operação contratual interna       PMAE
#
#                        tipo_credor  \
# 5  Instituição Financeira Nacional
#
#                                               credor moeda      valor  \
# 5  Banco Nacional de Desenvolvimento Econômico e ...  Real  7668000.0
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 5                 0                      0  16/03/2018

# %%
# 3) Município da Bahia com mais solicitações deferidas
ba_deferidos = dados_pvl('BA','Munic%C3%ADpio').interessado[ba_muni.status == 'Deferido']
ba_deferidos.value_counts()
# Out:
# Luís Eduardo Magalhães    14
# Vitória da Conquista      11
# Lauro de Freitas          10
# Camaçari                  10
# Barreiras                  8
#                           ..
# Sebastião Laranjeiras      1
# Sobradinho                 1
# Ribeirão do Largo          1
# Banzaê                     1
# Itaparica                  1
# Name: interessado, Length: 172, dtype: int64

# %%
# 4) Arquivo CSV com dados do Estado da Bahia, interessado = Estado

dados_pvl('BA','Estado').to_csv('Solicitacao_PVL_Bahia_Estado.csv')
